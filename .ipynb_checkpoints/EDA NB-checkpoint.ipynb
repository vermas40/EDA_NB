# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
import seaborn as sns
import time
sns.set()

# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina' 

# Increase the default plot size and set the color scheme
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['image.cmap'] = 'viridis'

# %%
os.chdir('E:\\Libraries\\Documents\\Side Hoes\\EDA')

# %%
dataset = pd.read_csv('Crashes_Last_Five_Years.csv')

# %%
def num_cat(df):
    num = df.select_dtypes(include=[np.number]).columns
    cat = list(set(df.columns) - set(num))
    
    datatypes = {
        'numeric' : num,
        'categorical' : cat
    }
    
    return datatypes

# %%
def uni_bi_numeric(df,data_types):
    print(df[data_types['numeric']].describe())

# %%
cc = dataset[data_cache['numeric']].corr().unstack().to_frame()

# %%
cc.loc[(cc[0] > 0.8) & (cc[0] < 1),].sort_values(by = 0)
# Out:
#                                             0
# PASSENGER         TOTAL_PERSONS      0.870425
# TOTAL_PERSONS     PASSENGER          0.870425
#                   NONINJURED         0.891019
# NONINJURED        TOTAL_PERSONS      0.891019
# PASSENGERVEHICLE  DRIVER             0.897831
# DRIVER            PASSENGERVEHICLE   0.897831
# MOTORCYCLE        MOTORIST           0.998673
# MOTORIST          MOTORCYCLE         0.998673
# X                 VICGRID_X          0.999872
# VICGRID_X         X                  0.999872
# LONGITUDE         VICGRID_X          0.999872
# VICGRID_X         LONGITUDE          0.999872
# VICGRID_Y         LATITUDE           0.999914
# LATITUDE          VICGRID_Y          0.999914
# VICGRID_Y         Y                  0.999914
# Y                 VICGRID_Y          0.999914
#                   LATITUDE           1.000000
# LATITUDE          Y                  1.000000
# LONGITUDE         X                  1.000000
# X                 LONGITUDE          1.000000
# MOTORIST          MOTORIST           1.000000
# PILLION           PILLION            1.000000
# PEDESTRIAN        PEDESTRIAN         1.000000
# UNKNOWN           UNKNOWN            1.000000
# PED_CYCLIST_5_12  PED_CYCLIST_5_12   1.000000
# X                 X                  1.000000
# OLD_PEDESTRIAN    OLD_PEDESTRIAN     1.000000
# OLD_DRIVER        OLD_DRIVER         1.000000
# YOUNG_DRIVER      YOUNG_DRIVER       1.000000
# NO_OF_VEHICLES    NO_OF_VEHICLES     1.000000
# HEAVYVEHICLE      HEAVYVEHICLE       1.000000
# PASSENGERVEHICLE  PASSENGERVEHICLE   1.000000
# PED_CYCLIST_13_18 PED_CYCLIST_13_18  1.000000
# UNLICENCSED       UNLICENCSED        1.000000
# OTHERINJURY       OTHERINJURY        1.000000
# PASSENGER         PASSENGER          1.000000
# Y                 Y                  1.000000
# OBJECTID          OBJECTID           1.000000
# NODE_ID           NODE_ID            1.000000
# LONGITUDE         LONGITUDE          1.000000
# LATITUDE          LATITUDE           1.000000
# VICGRID_X         VICGRID_X          1.000000
# VICGRID_Y         VICGRID_Y          1.000000
# DRIVER            DRIVER             1.000000
# TOTAL_PERSONS     TOTAL_PERSONS      1.000000
# FATALITY          FATALITY           1.000000
# SERIOUSINJURY     SERIOUSINJURY      1.000000
# MOTORCYCLE        MOTORCYCLE         1.000000
# NONINJURED        NONINJURED         1.000000
# MALES             MALES              1.000000
# FEMALES           FEMALES            1.000000
# BICYCLIST         BICYCLIST          1.000000
# INJ_OR_FATAL      INJ_OR_FATAL       1.000000
# PUBLICVEHICLE     PUBLICVEHICLE      1.000000

# %%
data_cache = num_cat(dataset)
tic = time.time()
#uni_bi_numeric(dataset,data_cache)
toc = time.time()
print('time elapse' + str(toc-tic))
# Out:
# time elapse0.0
